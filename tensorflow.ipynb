# %% [markdown]
# <a href="https://colab.research.google.com/github/EnzoRaphaelsjc/Atividade_JetpackCompose/blob/master/tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf


rank1_tensor = tf.Variable(["Test"], tf.string)
rank2_tensor = tf.Variable([["test", "ok", "penis"], ["test", "yes", "pe"],  ["test", "no","penis"]], tf.string)
tensor1 = tf.ones([1,2,4])  # tf.ones() creates a shape [1,2,3] tensor full of ones
tensor2 = tf.reshape(tensor1, [2,4,1])
print(tensor2)
# Out:
# tf.Tensor(
# [[[1.]
#   [1.]
#   [1.]
#   [1.]]
#
#  [[1.]
#   [1.]
#   [1.]
#   [1.]]], shape=(2, 4, 1), dtype=float32)
